# %%
using SeisMain, SeisProcessing, SeisPlot, SeisReconstruction

d=SeisLinearEvents()
dn = SeisAddNoise(d,9999)


Param = Dict(:dt=>0.002, :mu=>0.08, :filter_length=>2)
df = SeisFXDecon(dn,Param)
SeisPlotTX(style="wiggles",hcat(dn-df))
# Out:
# PyPlot.Figure(PyObject <Figure size 600x600 with 1 Axes>)
# im

# %%
get(Param,:mu,10.)
# Out:
# 0.08
